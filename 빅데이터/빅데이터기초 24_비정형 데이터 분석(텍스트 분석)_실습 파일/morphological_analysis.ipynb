# %%
# !pip install konlpy
# Out:
# ...
#    ---------------------------------------- 0.0/19.4 MB ? eta -:--:--
#    --------- ------------------------------ 4.5/19.4 MB 30.0 MB/s eta 0:00:01
#    -------------------------- ------------- 12.8/19.4 MB 35.0 MB/s eta 0:00:01
#    ---------------------------------------- 19.4/19.4 MB 38.3 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/4.0 MB ? eta -:--:--
#    ---------------------------------------- 4.0/4.0 MB 24.2 MB/s  0:00:00
# ...
#
#    ---------------------------------------- 0/3 [lxml]
#    ------------- -------------------------- 1/3 [JPype1]
#    ------------- -------------------------- 1/3 [JPype1]
#    -------------------------- ------------- 2/3 [konlpy]
#    ---------------------------------------- 3/3 [konlpy]
#
# ...

# %%
from konlpy.tag import Okt

text="아버지 가방에 들어가신다."

# Okt 객체 생성
okt = Okt()
# 형태소 분석
malist = okt.pos(text, norm=True, stem=True)
print(malist)
# Out:
# ---------------------------------------------------------------------------
# JVMNotFoundException                      Traceback (most recent call last)
# Cell In[2], line 6
#       3 text="아버지 가방에 들어가신다."
#       5 # Okt 객체 생성
# ----> 6 okt = Okt()
#       7 # 형태소 분석
#       8 malist = okt.pos(text, norm=True, stem=True)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\konlpy\tag\_okt.py:51, in Okt.__init__(self, jvmpath, max_heap_size)
#      49 def __init__(self, jvmpath=None, max_heap_size=1024):
#      50     if not jpype.isJVMStarted():
# ---> 51         jvm.init_jvm(jvmpath, max_heap_size)
#      53     oktJavaPackage = jpype.JPackage('kr.lucypark.okt')
#      54     OktInterfaceJavaClass = oktJavaPackage.OktInterface
#
# ...
