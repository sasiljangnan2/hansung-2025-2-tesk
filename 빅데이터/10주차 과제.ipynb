# %%
import numpy as np

# x 값과 y값
x=[5, 8]
y=[16, 24]

# x와 y의 평균값
mx = np.mean(x)
my = np.mean(y)
print("x의 평균값:", mx)
print("y의 평균값:", my)

# 기울기 공식의 분모
divisor = sum([(mx - i)**2 for i in x])

# 기울기 공식의 분자
def top(x, mx, y, my):
    d = 0
    for i in range(len(x)):
        d += (x[i] - mx) * (y[i] - my)
    return d
dividend = top(x, mx, y, my)

print("분모:", divisor)
print("분자:", dividend)

# 기울기와 y 절편 구하기
a = dividend / divisor
b = my - (mx*a)

# 출력으로 확인
print("기울기 a =", a)
print("y 절편 b =", b)
# Out:
# x의 평균값: 6.5
# y의 평균값: 20.0
# 분모: 4.5
# 분자: 12.0
# 기울기 a = 2.6666666666666665
# y 절편 b = 2.666666666666668

# %%
# 예측에 활용하기

xp=6

y=a*xp+b

print("예측값 =", y)
# Out:
# 예측값 = 18.666666666666668
